# %% [markdown]
# <div align="center">
#     <img src="https://i.pinimg.com/736x/04/41/52/0441528e0396b38e72d182acc0529f17.jpg" width="300px" alt="Logo University of Pisa">
# </div>

# %% [markdown]
# # Introduction
#
# This notebook, titled "Holocron", is an information retrieval system. Inspired by the ancient, knowledge-storing artifacts of the Star Wars universe, Holocron implements custom text preprocessing, lexicon generation, inverted and direct indexing, BM25 scoring, and Document-At-A-Time (DAAT) candidate traversal. Evaluated against the Vaswani corpus using standard TREC benchmarks.
#
# ### Key Features:
# - **Document Preprocessing:** Implements robust methods for cleaning, normalizing, and tokenizing documents to prepare them for indexing.
# - **Advanced Indexing Structures:** Constructs efficient data structures such as an inverted index, direct index, and lexicon to enable fast and accurate document retrieval.
# - **BM25 Scoring:** Utilizes the BM25 algorithm to rank documents based on their relevance to a query.
# - **DAAT Algorithm:** Applies the Document-At-A-Time (DAAT) approach for efficient query processing across large datasets.

# %% [markdown]
# ## Dataset Overviwe
#
# **Title:** Vaswani Dataset
#
# **Description:**
# For this Information Retrieval project, I am using the Vaswani dataset from the ir_datasets collection. This dataset features a focused corpus of roughly **11,000 scientific abstracts** paired with natural language queries and corresponding relevance judgments, making it ideal for retrieval experiments in scientific literature.
#
# ---
#
# **Dataset Properties:**
#
# | **Property**           | **Details**                                          |
# |------------------------|------------------------------------------------------|
# | **Documents**          | ~11,000 scientific abstracts                         |
# | **Queries**            | 93 natural language queries                          |
# | **Relevance Judgments**| 2,083 qrels (all labeled as relevant)                |
# | **Language**           | English                                              |
#
# ---
#
# **Dataset Structure:**
#
# - **Document Type:**
#   - **GenericDoc:** A named tuple with fields:
#     - `doc_id`: Unique document identifier
#     - `text`: Full text of the scientific abstract
#
# - **Query Type:**
#   - **GenericQuery:** A named tuple with fields:
#     - `query_id`: Unique query identifier
#     - `text`: Query text
#
# - **Relevance Judgments:**
#   - **TrecQrel:** A named tuple with fields:
#     - `query_id`: Query identifier
#     - `doc_id`: Document identifier
#     - `relevance`: Relevance label (1 indicates relevance)
#     - `iteration`: (Additional field for iteration info)

# %% [markdown]
# ## Necessary libraries
# This cell imports all required Python libraries and modules for the project.
# These libraries cover text preprocessing, performance optimization,
# file handling, and evaluation metrics for information retrieval.
# Key Libraries:
#
# - `nltk` for natural language processing {stemming (reducing words to their root form), stopwords(For removing common words like "the", "is", etc.)}.
# - `wordninja` For splitting concatenated words into smaller components
# - `re` Regular expressions for pattern matching in text
# -`unicodedata` For text normalization (e.g., converting characters to consistent form)
# - `pyterrier` For information retrieval tasks (search engines, ranking)
# -`ir_measures` For evaluation metrics in information retrieval
# - `string` For handling and removing punctuation
# - `gc` for garbage collection and memory management.
# - `tqdm`  For showing progress bars in loops
# - `heapq` for working with priority queues (heaps).
# - `tarfile` for extracting tar files.
# - `os` For interacting with the operating system (e.g., file paths, environment variables)
# - `polars`High-performance data processing library, alternative to pandas
# - `matplotlib.pyplot` for plotting and visualizing data.
# - `collections` (defaultdict, Counter) for efficient data structures.

# %%
#Installing required packages
# !pip install wordninja pyterrier ir_measures polars python-terrier

# %%
# --- 1. Text Processing and Natural Language Processing (NLP) ---
import re
import string
import nltk
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
nltk.download('stopwords', quiet=True)
import unicodedata
import wordninja

# --- 2. Data Structures and Utilities ---
from collections import defaultdict, Counter
import heapq
import math

# --- 3. File Handling and Data Storage ---
import pandas as pd
import polars as pl

# --- 4. Performance and Memory Management ---
import gc
from tqdm import tqdm
from functools import lru_cache

# --- 5. Information Retrieval (IR) ---
import pyterrier as pt
import ir_measures

# --- 6. Visualization and Plotting ---
import matplotlib.pyplot as plt

# %% [markdown]
# ##Memory Management
# ###Garbage Collection (gc):
#
# The gc module helps in automatic memory management by clearing unused memory objects. This is important for systems dealing with large datasets like an IR system, where memory usage can grow quickly.

# %%
gc.enable()

# %% [markdown]
# # Preprocessing
#
# In this cell, we perform several key steps to clean, normalize, and prepare the input text for further analysis in our Information Retrieval (IR) system.
#
# #### 1. **Normalization and Encoding:**
# - **Unicode Normalization (NFKD)**: We apply **NFKD (Normalization Form KD)** using `unicodedata.normalize("NFKD", text)`. This decomposes characters into their base form and separates diacritical marks. For example, "é" (a single composed character) is converted into "e" + "´" (base letter + accent). This helps in standardizing text for further processing.
# - **Encoding**: The text is then encoded into ASCII using `.encode('ASCII', 'ignore')`, which removes any non-ASCII characters, such as emojis or special symbols, that may cause issues during analysis.
# - **Decoding**: After encoding, we decode the text back to UTF-8 using `.decode("utf-8")` to maintain compatibility with further processing steps.
# - **Lowercasing**: The text is converted to lowercase using `.lower()` to ensure consistency, as case differences (e.g., "Hello" vs. "hello") should not affect word matching.
#
# #### 2. **Removing Unwanted Patterns (Acronyms, URLs, and Emails):**
# - **Acronyms**: The regex pattern `\b(?:[A-Za-z]\.){2,}` matches acronyms (e.g., "U.S.A.") and removes the periods by replacing them with empty strings.
# - **URLs**: The patterns `http\S+` and `www\S+` match URLs starting with "http" and "www" respectively. These are replaced with spaces to remove them from the text.
# - **Emails**: The pattern `\S+@\S+` matches email addresses and replaces them with spaces.
#
# #### 3. **Removing Punctuation:**
# - **Punctuation Removal**: The translation table created by `str.maketrans()` replaces all punctuation characters (from `string.punctuation`) with spaces. This helps eliminate unnecessary symbols that don't carry meaning for many text processing tasks.
#
# #### 4. **Tokenization, Splitting Long Words, and Stopword Removal:**
# - **Tokenization**: The text is split into individual words using the `split()` function. This makes it easier to work with each word individually.
# - **Avoiding Consecutive Duplicates**: We use the `current` variable to avoid adding consecutive duplicates. This ensures that the same word doesn't appear twice in a row due to tokenization or splitting.
#
#  ***Example:***
#   For the text:
#   `"hello hello world world hello"`
#   The process will yield:
#   `["hello", "world", "hello"]`
#   (Note that only consecutive duplicates are removed.)
#
# #### 5. **Splitting Long Words (If Necessary):**
# - **Splitting Long Words**: If a word is longer than 10 characters, we use the `split_word()` function (from the `wordninja` library) to split it into smaller, more manageable sub-words. This is especially useful for handling compound words that are concatenated without spaces.
#
#  ***Example:***
#   Consider the long concatenated word:
#   `"thisisaverylongcompoundword"`
#   Using `wordninja.split(word)`, it might be split into:
#   `["this", "is", "a", "very", "long", "compound", "word"]`
#   This makes the text easier to process and match against the lexicon.
#
#
# #### 6. **Stopword Removal and Stemming:**
# - **Stopwords Removal**: We check each word (or sub-word, if it was split) against a list of common "stopwords" (such as "the", "and", "is"). These are typically removed because they do not contribute much meaningful information in text analysis.
# - **Stemming**: After removing stopwords, we apply stemming using the `SnowballStemmer` from NLTK. Stemming reduces words to their root form (e.g., "running" becomes "run"). This allows us to treat different forms of the same word as equivalent.
#
# #### **Output:**
# The final output of the `preprocess` function is a list of **preprocessed words**. This list consists of tokens that have been cleaned, normalized, tokenized, split, and stemmed, with stopwords removed.

# %%
# ----------------------------------------------------
# 1. Precompile regex patterns and initialize globals
# ----------------------------------------------------
acronym_regex = re.compile(r"\b(?:[A-Za-z]\.){2,}")
url_http_regex = re.compile(r"\s?http\S+")
url_www_regex = re.compile(r"\s?www\S+")
email_regex = re.compile(r"\S+@\S+")
punct_trans_table = str.maketrans(string.punctuation, " " * len(string.punctuation))

# Cache the stopwords and stemmer as globals so they are not re-created on every call.
stopwords_set = set(stopwords.words("english"))
stemmer = SnowballStemmer("english")

# ----------------------------------------------------
# 2. Define the helper functions using the precompiled objects
# ----------------------------------------------------
def split_word(word):
    """Splits a long word into smaller components using wordninja."""
    return wordninja.split(word)

def preprocess(text):
    """
    Cleans, normalizes, tokenizes, and stems the input text.
    Returns:
        list[str]: Preprocessed and stemmed tokens.
    """
    # Normalize and encode text
    text = unicodedata.normalize("NFKD", text).encode('ASCII', 'ignore').decode("utf-8").lower()

    # Remove acronyms (e.g., "U.S.A.")
    text = acronym_regex.sub(lambda x: x.group().replace('.', ''), text)

    # Remove URLs and emails
    text = url_http_regex.sub(' ', text)
    text = url_www_regex.sub(' ', text)
    text = email_regex.sub(' ', text)

    # Remove punctuation (by replacing punctuation with spaces)
    text = text.translate(punct_trans_table)

    words = text.strip().split()
    words_with_no_close_duplicate = []
    current = ""

    for word in words:
        if word != current:  # Skip consecutive duplicates
            # Split long words into subwords if needed
            splitted_words = split_word(word) if len(word) > 10 else [word]
            for splitted_word in splitted_words:
                if splitted_word not in stopwords_set:
                    words_with_no_close_duplicate.append(stemmer.stem(splitted_word))
            current = word

    return words_with_no_close_duplicate

# %% [markdown]
# #**IR Data Structures**

# %% [markdown]
# ## **Index Construction**
# In this section, the `build_index` function constructs an **inverted index** and other supporting data structures for an **Information Retrieval (IR) system**. The implementation is **modular**, with clearly defined responsibilities across multiple functions to improve **readability, maintainability, and performance**.
#
# ## **Overview of the Indexing Process**
# The indexing process involves:
#
# - **Lexicon Construction**: Assigning unique term IDs to words and tracking their frequency.
# - **Direct Indexing**: Mapping documents to the terms they contain.
# - **Inverted Indexing**: Mapping terms to the documents they appear in.
# - **Document Statistics**: Storing document lengths and token counts.
#
# This implementation efficiently processes a dataset containing **documents** (`docno`) and their **tokens** (preprocessed words).

# %% [markdown]
# ### **Initializing Index Data Structures**
# ### **Purpose:**
# This function **creates and initializes** all required data structures:
#
# - **`lexicon`**: Maps tokens (terms) to `[termid, document frequency, term frequency]`.
#   - `termid`: A unique identifier for each term.
#   - `document frequency`: Number of documents containing the term.
#   - `term frequency`: Total occurrences of the term across all documents.
# - **`doc_index`**: Stores document lengths as tuples `(docid, doclen)`, where `doclen` is the number of tokens in the document.
# - **`direct_index`**: Maps document IDs to term IDs and their term frequencies.
# - **`inv_d` & `inv_f`**: Store **inverted index** data:
#   - **`inv_d`**: Maps term IDs to document IDs.
#   - **`inv_f`**: Maps term IDs to their frequency in each document.

# %%
def setup_index_structures():
    """
    Initializes the required data structures for indexing.

    Returns:
        tuple: Empty structures for lexicon, document index, direct index, and inverted index.
    """
    lexicon = defaultdict(lambda: [0, 0, 0])  # [termid, document frequency, term frequency]
    doc_index = []
    direct_index = defaultdict(dict)
    inv_d, inv_f = defaultdict(list), defaultdict(list)  # Inverted index storage
    return lexicon, doc_index, direct_index, inv_d, inv_f

# %% [markdown]
# ### **Lexicon Management**
# ### **Purpose:**
# - Assigns a **unique ID** (`termid`) to each token.
# - Uses `termid_counter` (a **mutable list**) to maintain a **global term ID counter**.
#
# ### **Why use `termid_counter` as a list?**
# - Python **integers are immutable**, so they **cannot** be modified inside a function.
# - Using a **list** (`termid_counter[0]`) allows modifying it **in-place**.

# %%
def update_lexicon(token, lexicon, termid_counter):
    """
    Updates the lexicon with a new token if it does not exist.

    Parameters:
        token (str): The token to be added.
        lexicon (dict): The lexicon mapping tokens to metadata.
        termid_counter (list[int]): Mutable counter for term IDs.

    Returns:
        int: The term ID of the token.
    """
    if token not in lexicon:
        lexicon[token][0] = termid_counter[0]
        termid_counter[0] += 1
    return lexicon[token][0]

# %% [markdown]
# ### **Processing Individual Documents**
# ### **Purpose:**
# - **Counts token frequencies** in the document using `Counter`.
# - Calls `update_lexicon()` to assign a term ID.
# - Updates the followings:
#   - **Inverted Index** (`inv_d`, `inv_f`).
#   - **Direct Index** (`direct_index`).
#   - **Lexicon Statistics** (`lexicon`).
# - Returns **document length** (`doclen`).
#
# ### **Data Structures Updated:**
# - **`lexicon`**: Maps tokens (terms) to `[termid, document frequency, term frequency]`.
# - **`direct_index`**: Stores term-document mappings.
# - **`inv_d`**: Stores document occurrences per term.
# - **`inv_f`**: Stores term frequency per document.

# %%
def process_document(docid, tokens, lexicon, direct_index, inv_d, inv_f, termid_counter):
    """
    Processes a single document, updating all index structures.

    Parameters:
        docid (int): The document identifier.
        tokens (list[str]): The list of tokens in the document.
        lexicon (dict): Lexicon mapping tokens to term IDs and statistics.
        direct_index (dict): Direct index mapping doc IDs to term frequencies.
        inv_d (dict): Inverted index storing document occurrences per term.
        inv_f (dict): Inverted index storing term frequencies per document.
        termid_counter (list[int]): Mutable counter for assigning term IDs.

    Returns:
        int: The length of the document (number of tokens).
    """
    token_tf = Counter(tokens)  # Count term frequencies within the document

    for token, tf in token_tf.items():
        token_id = update_lexicon(token, lexicon, termid_counter)

        # Update inverted and direct index
        inv_d[token_id].append(docid)
        inv_f[token_id].append(tf)
        direct_index[docid][token_id] = tf

        # Update lexicon statistics
        lexicon[token][1] += 1  # Document frequency
        lexicon[token][2] += tf  # Term frequency

    return len(tokens)

# %% [markdown]
# ### **Main Index Construction**
# ### **Purpose:**
# - **Initializes** all indexing structures.
# - Iterates over each document using `tqdm` for **progress tracking**.
# - Calls `process_document()` for each document's **tokens**.
# - Updates **document statistics** (`num_docs`, `num_terms`, `num_tokens`).
#
# ### **Returns:**
# - **`lexicon`**: Term metadata.
# - **`inverted_index`**: `{docids, freqs}`.
# - **`doc_index`**: Document lengths.
# - **`direct_index`**: Term-document mappings.
# - **`stats`**: Summary statistics.

# %%
def build_index(dataset):
    """
    Constructs an inverted index and other supporting structures from the input dataset.

    Parameters:
        dataset (DataFrame): A pandas DataFrame with the following columns:
            - 'docno': Unique identifier for each document.
            - 'tokens': List of tokens for the document.

    Returns:
        tuple: A collection of indices and statistics:
            - lexicon (dict): Maps tokens to their metadata [termid, document frequency, term frequency].
            - inverted_index (dict): Contains document IDs ('docids') and term frequencies ('freqs').
            - doc_index (list): List of tuples (docid, doclen), where doclen is the number of tokens in each document.
            - direct_indexfreqs (dict): Maps document IDs to term IDs and their term frequencies.
            - stats (dict): Summary statistics.
    """
    lexicon, doc_index, direct_index, inv_d, inv_f = setup_index_structures()
    termid_counter = [0]  # Using a mutable list for consistent term ID tracking
    total_tokens = 0

    for row in tqdm(dataset.itertuples(index=False), desc="Indexing", total=len(dataset)):
        docid = int(row.docno)
        tokens = row.tokens
        doclen = process_document(docid, tokens, lexicon, direct_index, inv_d, inv_f, termid_counter)
        doc_index.append((docid, doclen))
        total_tokens += doclen

    stats = {
        "num_docs": len(dataset),
        "num_terms": len(lexicon),
        "num_tokens": total_tokens,
    }

    return dict(lexicon), {"docids": dict(inv_d), "freqs": dict(inv_f)}, doc_index, dict(direct_index), stats

# %% [markdown]
# ## **InvertedIndex**
#
# The `InvertedIndex` class represents an **inverted index** used in information retrieval systems.
# It allows **efficient document retrieval** based on term queries and supports the **BM25 ranking function**.
#
# ### Key Responsibilities
# - Stores the mapping of terms to documents (**Lexicon** & **Inverted Index**).
# - Manages document metadata (**Document Index**).
# - Implements **BM25 ranking** to score documents based on query terms.
# - Provides efficient **posting list iteration** for search operations.
#
# ### Main Components
# - **Lexicon (`lexicon`)**: Maps terms to metadata like term IDs and frequencies.
# - **Inverted Index (`inv`)**: Maps term IDs to **posting lists** of documents.
# - **Document Index (`doc`)**: Stores document IDs and their lengths.
# - **Direct Index (`direct`)**: Maps document IDs to term frequencies.
# - **Statistics (`stats`)**: Stores global collection stats (e.g., total number of documents).
# - **BM25 Parameters (`K`, `B`)**: Used for document ranking.

# %% [markdown]
# ### **Nested Class: `PostingListIterator`**
# The `PostingListIterator` class is **a helper class inside `InvertedIndex`** that iterates over a term's posting list.
#
# ### Why is this useful?
# - Allows **efficient traversal** of documents containing a specific term.
# - Computes **BM25 scores** for ranking documents.
# - Provides functions to **jump** to a target document efficiently.
#
# ### Attributes
# | Attribute | Description |
# |-----------|------------|
# | `docids` | List of document IDs where the term appears. |
# | `freqs` | Term frequencies in each document. |
# | `doclens` | A dictionary mapping document IDs to document lengths. |
# | `N` | Total number of documents in the collection. |
# | `avgdl` | Average document length. |
# | `K, B` | BM25 parameters for controlling term saturation and length normalization. |
# | `pos` | Current position in the posting list. |

# %% [markdown]
# ####Methods
#
# ## `docid()`: Get Current Document ID
# **Purpose**:
# Returns the document ID at the current iterator position.
#
# **Returns**:
# - `int`: Document ID.
# - `math.inf`: If the iterator reaches the end.
#
# ---
#
# ###**`score()`: Compute BM25 Score**
# **Purpose**:
# Computes the **BM25 relevance score** of the current document.
#
# **Formula**:
#
# $$
# BM25(i) = \log \frac{N}{df_i} \times \frac{tf_i}{K \cdot ((1 - B) + B \cdot dl_i / avgdl) + tf_i}$$
#
#
#
# Where:
# - \( tf_i \) = Term frequency in the document.
# - \( df_i \) = Document frequency (number of documents containing the term).
# - \( dl_i \) = Length of the current document.
# - \( avgdl \) = Average document length in the collection.
# - \( N \) = Total number of documents.
# - \( K, B \) = BM25 parameters.
#
# **Returns**:
# - `float`: BM25 score.
# - `math.inf`: If iterator reaches the end.
#
#
# ---
#
# ### **`next(target)`: Move Iterator**
# **Purpose**:
# Moves the iterator:
# - To the **next document** if no target is given.
# - To a **specific document ID** if `target` is provided.
#
# **Parameters**:
# - `target` *(int, optional)*: The document ID to jump to.
#
# **Efficiency**:
# If `target` is given, it **skips over documents**, making retrieval faster.
#
# ---
#
#
# ###**`is_end_list()`**:
#
# **Purpose**:
#
#   - Checks if the iterator has reached the end of the posting list.
#
# ---
#
# ###**`len()`**:
# **Purpose**:
#    - Returns the total number of documents in the posting list.

# %% [markdown]
# ###**`InvertedIndex` Class Constructor**
#
# **Purpose:**
# Initializes an instance of the InvertedIndex class with the provided lexicon, inverted index, document index, direct index, statistics, and BM25 parameters (K, B).
#
# ## Attributes
# | Attribute | Description |
# |-----------|------------|
# | `lexicon` | A dictionary mapping terms to metadata like term IDs and frequencies. |
# | `inv` |  An inverted index containing term IDs and posting lists (document IDs and term frequencies). |
# | `doc` |  A list of documents, each containing a document ID and length. `(docid, doclen)`. |
# | `direct` | Direct index: Maps document IDs to term frequencies. |
# | `stats` | A dictionary containing collection statistics like the total number of documents. |
# | `N` | Total number of documents. |
# | `doclens` | A dictionary mapping document IDs to document lengths. |
# | `avgdl` | Average document length in the collection. |
# | `K, B` | BM25 scoring parameters. |

# %% [markdown]
# ####**Methods**
# ###**`num_docs()`**
# **Purpose**:
# Returns the **total number of documents** in the index.
#
# **Why is this important?**
# - Used in **BM25 scoring** to compute the **inverse document frequency (IDF)**.
# - Helps in **normalizing** scores based on collection size.
#
# **Returns**:
# - `int`: Total number of documents.
#
# ###**`get_posting(termids)`**
# **Purpose**:
# Fetches the **posting list** of a given term.
#
# **How does it work?**
# - Looks up the **term ID** in `lexicon`.
# - Retrieves document IDs & term frequencies from `inv` index.
# - Returns a `PostingListIterator` for **efficient iteration**.
#
# **Returns**:
# - `PostingListIterator`: Iterator for the posting list `list[PostingListIterator]`.
# - `[]`: If the term does not exist.
#
# ### **`get_termids(tokens)`**
# **Purpose**:
# Retrieves the term IDs for a list of tokens (terms).
#
# **How does it work?**
# - For each token in the tokens list (of the query), it checks whether the token exists in the lexicon.
# -If found, it retrieves the term ID associated with the token.
# -Returns a list of term IDs for the tokens.
#
# **Returns**:
# - `list[int]`: A list of term IDs corresponding to the tokens in the input list.
# - `[]`: If a token is not found in the lexicon.
#
# ### **`get_postings(termids)`**:
#    - Retrieves a list of posting lists for the provided term IDs.
#    - Returns a list of `PostingListIterator` objects, one for each term ID.

# %%
class InvertedIndex:
    """
    Represents an inverted index for document retrieval.

    This class provides methods to manage the lexicon, inverted index, document index, and retrieval statistics.
    It also supports BM25 scoring for ranking documents based on term relevance.

    Attributes:
        lexicon (dict): Mapping of terms to metadata (e.g., term ID, frequencies).
        inv (dict): Inverted index containing 'docids' and 'freqs'.
        doc (list): Document index containing document IDs and their lengths.
        direct (dict): Direct index mapping document IDs to term IDs and their frequencies.
        stats (dict): Index statistics, including number of documents.
        N (int): Total number of documents in the collection.
        avgdl (float): Average document length.
        K (float): BM25 parameter for term frequency scaling.
        B (float): BM25 parameter for document length normalization.
    """

    class PostingListIterator:
        """
        Iterates over a posting list for a given term, supporting BM25 scoring.

        Attributes:
            docids (list): List of document IDs containing the term.
            freqs (list): Term frequencies in each document.
            doclens (dict): Mapping of document IDs to their lengths.
            N (int): Total number of documents.
            avgdl (float): Average document length.
            K (float): BM25 parameter for term frequency scaling.
            B (float): BM25 parameter for document length normalization.
        """
        def __init__(self, docids, freqs, doclens, N, avgdl, k, b):
            self.docids = docids
            self.freqs = freqs
            self.doclens = doclens
            self.N = N
            self.avgdl = avgdl
            self.K = k
            self.B = b
            self.pos = 0  # Current position in the posting list


        def docid(self):
            """
            Returns the document ID at the current iterator position.

            Returns:
                int: The current document ID, or math.inf if the list has ended.
            """
            if self.is_end_list():
                return math.inf
            return self.docids[self.pos]

        def score(self):
            """
            Computes the BM25 score for the current document.

            Returns:
                float: The BM25 score for the document, or math.inf if the list has ended.
            """
            if self.is_end_list():
                return math.inf

            tf_i = self.freqs[self.pos]
            dl_i = self.doclens.get(self.docid())
            df_i = self.len()

            return 0 if df_i == 0 else (tf_i / (self.K * ((1 - self.B) + self.B * dl_i / self.avgdl) + tf_i)) * math.log(self.N / df_i)

        def next(self, target=None):
            """
            Advances the iterator to the next position or to a target document ID.

            Parameters:
                target (int, optional): The target document ID to jump to. Defaults to None.
            """
            if not target:
                if not self.is_end_list():
                    self.pos += 1
            else:
                if target > self.docid():
                    try:
                        self.pos = self.docids.index(target, self.pos)
                    except ValueError:
                        self.pos = len(self.docids)

        def is_end_list(self):
            """
            Checks if the iterator has reached the end of the posting list.

            Returns:
                bool: True if the list has ended, False otherwise.
            """
            return self.pos == len(self.docids)

        def len(self):
            """
            Returns the length of the posting list.

            Returns:
                int: The number of documents in the posting list.
            """
            return len(self.docids)

    def __init__(self, lex, inv, doc, direct, stats, k, b):
        self.lexicon = lex
        self.inv = inv
        self.doc = doc
        self.direct = direct
        self.stats = stats
        self.N = self.num_docs()
        self.doclens = {int(doc_entry[0]): doc_entry[1] for doc_entry in self.doc}
        total_dl = sum(doc_entry[1] for doc_entry in self.doc)
        self.avgdl = total_dl / self.N
        self.K = k
        self.B = b

    def num_docs(self):
        """
        Returns the total number of documents.

        Returns:
            int: Total document count.
        """
        return self.stats['num_docs']

    def get_posting(self, termid):
        """
        Retrieves the posting list iterator for a given term ID.

        Parameters:
            termid (int): The ID of the term.

        Returns:
            PostingListIterator: An iterator for the term's posting list.
        """
        docids = self.inv['docids'].get(termid)
        freqs = self.inv['freqs'].get(termid)

        return InvertedIndex.PostingListIterator(
            docids=docids,
            freqs=freqs,
            doclens=self.doclens,
            N=self.N,
            avgdl=self.avgdl,
            k=self.K,
            b=self.B
        )

    def get_termids(self, tokens):
        """
        Retrieves the term IDs for a list of tokens.

        Parameters:
            tokens (list[str]): List of tokens.

        Returns:
            list[int]: List of term IDs.
        """
        return [self.lexicon[token][0] for token in tokens if token in self.lexicon]

    def get_postings(self, termids):
        """
        Retrieves the posting list iterators for a list of term IDs.

        Parameters:
            termids (list[int]): List of term IDs.

        Returns:
            list[PostingListIterator]: List of posting list iterators for the terms.
        """
        return [self.get_posting(termid) for termid in termids]

# %% [markdown]
# # DAAT Algorithm
#
# The Document-At-A-Time (DAAT) algorithm processes multiple posting lists in parallel, advancing through each list simultaneously to identify candidate documents for multi-term queries. This approach allows for early elimination of non-relevant documents and minimizes unnecessary comparisons.
#
# - Support for Boolean and Phrasal Queries
# - Efficiency for skipping irrilevance Documents

# %% [markdown]
# ## Components of DAAT

# %% [markdown]
# ### **Function: `get_min_docid`**
# In an inverted index, each posting list is constructed by scanning through the documents, typically in the order of document IDs. As a result, the document IDs in each posting list are stored in sorted order. This ordering is essential because it allows for efficient merging and retrieval of documents when processing queries.
#
# The `get_min_docid` function leverages the sorted order by iterating over each posting list iterator and retrieving the current document ID (using the `docid()` method) from those lists that still have pending documents. Because the posting lists are sorted, the smallest pending document ID among all iterators is chosen as the next candidate for processing.This mechanism enables a **single-pass traversal** of the posting lists, making the retrieval process efficient and ensuring each document is processed only once.
#
# ### **Parameters**
# | Parameter  | Type                              | Description |
# |------------|-----------------------------------|-------------|
# | `postings` | `list[PostingListIterator]`      | A list of posting list iterators, each providing access to a document list associated with a term. |
#
# ### **Returns**
# | Return Type | Description |
# |-------------|-------------|
# | `int`       | The smallest pending document ID (`docid`) among the posting list iterators. Returns `math.inf` if all posting lists are finished. |
#
# ### **Functionality**
# 1. **Initialize `min_docid` to `math.inf`**: This ensures that any valid document ID encountered will be smaller than the initial value.
# 2. **Iterate through each posting list iterator (`p`)**:
#    - If the iterator is **not finished** (`p.is_end_list()` is `False`):
#      - Retrieve the current `docid` using `p.docid()`.
#      - Update `min_docid` with the smaller value between `p.docid()` and `min_docid`.
# 3. **Return `min_docid`**:
#    - If at least one posting list contains pending documents, the function returns the smallest `docid`.
#    - If all posting lists are finished, it returns `math.inf`, signaling that no documents remain.
#
# ### **Edge Cases Considered**
# - If all posting lists are **empty or fully traversed**, the function returns `math.inf`.
# - Handles scenarios where some posting lists are **still pending while others are finished**.
# - Efficiently finds the **smallest pending document ID** in **O(n) time complexity**, where `n` is the number of posting list iterators.
# - This function is a key component in **merging multiple posting lists efficiently** for query processing in an **inverted index-based search engine**.

# %%
def get_min_docid(postings):
    """
    Finds the smallest pending document ID (docid) among the provided postings.

    Parameters:
        postings (list[PostingListIterator]): List of posting list iterators.

    Returns:
        int: The smallest pending document ID, or math.inf if all postings are finished.
    """
    min_docid = math.inf
    for p in postings:
        if not p.is_end_list():  # Check if the posting list has not been fully traversed
            min_docid = min(p.docid(), min_docid)
    return min_docid

# %% [markdown]
# ### **TopKPriorityQueue Class**
#
# The `TopKPriorityQueue` class implements a priority queue designed to maintain the top-k elements based on their scores. This data structure is essential for efficiently managing and updating a limited set of the highest-scoring items, commonly used in information retrieval algorithms like Document-At-A-Time (DAAT).
#
# ## **Attributes**
# The following table describes the attributes of the `TopKPriorityQueue` class:
#
# | Attribute  | Type  | Description  |
# |------------|-------|--------------|
# | `queue`    | `list` | A min-heap that stores tuples of `(score, docid)`. The smallest score in the heap is at the root. |
# | `k`        | `int` | The maximum capacity of the queue, determining how many top items can be stored. |
# | `threshold` | `float` | The minimum score required for an element to be considered for insertion into the queue. |
#
# ---
#
# ## **Methods**
#
# ### **1. `__init__(self, k=10, threshold=0.0)`**
# **Purpose:**
# Initializes the `TopKPriorityQueue` instance with a given maximum capacity (`k`) and an optional threshold.
#
# **Parameters:**
# - `k` (`int`): Maximum size of the queue. Defaults to 10.
# - `threshold` (`float`): Initial threshold value. Defaults to 0.0.
#
# ---
#
# ### **2. `size(self)`**
# **Purpose:**
# Returns the current number of elements in the queue.
#
# **Returns:**
# - `int`: The number of items currently in the queue.
#
# ---
#
# ### **3. `is_eligible(self, score)`**
# **Purpose:**
# Determines whether a given score exceeds the current threshold and could be added to the queue.
#
# **Parameters:**
# - `score` (`float`): The score to evaluate against the threshold.
#
# **Returns:**
# - `bool`: `True` if the score exceeds the threshold, otherwise `False`.
#
# ---
#
# ### **4. `reset(self, new_threshold=None)`**
# **Purpose:**
# Clears the queue and optionally updates the threshold.
#
# **Parameters:**
# - `new_threshold` (`float`, optional): If provided, updates the queue’s threshold to this new value.
#
# **Behavior:**
# - Resets the queue to an empty list.
# - Updates the `threshold` attribute if a new value is provided.
#
# ---
#
# ### **5. `__repr__(self)`**
# **Purpose:**
# Provides a string representation of the `TopKPriorityQueue` instance for debugging and logging purposes.
#
# **Returns:**
# - `str`: A formatted string describing the queue's current state.
#
# **Example Output:**
# <6 items, th=4.0 [(4.0, 1), (5.0, 2), (9.0, 3)]>
#
#
# ---
#
# ### **6. `add(self, docid, score)`**
# **Purpose:**
# Attempts to insert a `(docid, score)` pair into the queue. The insertion only occurs if the score exceeds the threshold.
#
# **Parameters:**
# - `docid` (`int`): The unique identifier for the document.
# - `score` (`float`): The score associated with the document.
#
# **Returns:**
# - `bool`: `True` if the item was successfully inserted, `False` otherwise.
#
# **Behavior:**
# 1. If `score` is greater than `threshold`:
#    - If the queue has reached its maximum capacity (`k`), replace the root element (smallest score) using `heapq.heapreplace` if the new score is higher.
#    - If the queue is not full, add the new `(score, docid)` pair using `heapq.heappush`.
# 2. Updates the `threshold`:
#    - If the queue is full, the threshold is set to the smallest score in the queue (`queue[0][0]`).
#
# ---
#
# ## **Heap Behavior**
# The `queue` is maintained as a **min-heap**, ensuring that:
# - The smallest score is always at the root.
# - Insertions and deletions operate efficiently, maintaining the top-k elements.

# %%
class TopKPriorityQueue:
    """
    A priority queue to manage the top-k elements with a dynamic threshold.

    Attributes:
        queue (list): The internal priority queue storing (score, docid) tuples.
        k (int): Maximum capacity of the queue.
        threshold (float): Current threshold to determine if a new element enters the queue.
    """

    def __init__(self, k=10, threshold=0.0):
        """
        Initializes the queue with a maximum capacity and an initial threshold.

        Parameters:
            k (int): Maximum size of the queue. Defaults to 10.
            threshold (float): Initial threshold value. Defaults to 0.0.
        """
        self.queue = []
        self.k = k
        self.threshold = threshold

    def get_size(self):
        """
        Returns the number of elements in the queue.

        Returns:
            int: The current size of the queue.
        """
        return len(self.queue)

    def is_eligible(self, score):
        """
        Checks if a score exceeds the current threshold.

        Parameters:
            score (float): The score to evaluate.

        Returns:
            bool: True if the score exceeds the threshold, False otherwise.
        """
        return score > self.threshold

    def reset(self, new_threshold=None):
        """
        Clears the queue and optionally updates the threshold.

        Parameters:
            new_threshold (float, optional): The new threshold value. Defaults to None.
        """
        self.queue = []
        if new_threshold is not None:
            self.threshold = new_threshold

    def __repr__(self):
        """
        Returns a string representation of the queue.

        Returns:
            str: A string describing the queue's state.
        """
        return f'<{self.get_size()} items, th={self.threshold} {self.queue}>'

    def add(self, docid, score):
        """
        Inserts an element into the queue if the score exceeds the threshold.

        Parameters:
            docid (int): Document ID associated with the score.
            score (float): The score to insert.

        Returns:
            bool: True if the element was inserted, False otherwise.
        """
        if score > self.threshold:
            if self.get_size() >= self.k:
                heapq.heapreplace(self.queue, (score, docid))
            else:
                heapq.heappush(self.queue, (score, docid))
            if self.get_size() >= self.k:
                self.threshold = max(self.threshold, self.queue[0][0])
            return True
        return False

# %% [markdown]
# ##  Algorithm Implementation
#
# ### Purpose:
# The `daat` function implements the **Document-At-A-Time (DAAT)** retrieval algorithm. Its goal is to combine scores from multiple posting lists—each representing documents containing a specific query term—into a single ranked list of documents. DAAT is used because it allows for efficient, simultaneous processing of multiple posting lists, making it well-suited for handling large-scale document collections. By iterating over the documents across posting lists in parallel, DAAT minimizes redundant work and quickly identifies the most relevant documents. This approach is particularly advantageous when working with ranking models like BM25, as it aggregates term scores on a per-document basis, ensuring that the top-k scoring documents are efficiently retrieved.
#
# ### Parameters:
# - **postings** (list of `PostingListIterator`):
#   A list of posting list iterators, where each iterator corresponds to a term’s posting list.
#   Each `PostingListIterator` provides:
#   - `docid()`: Returns the current document ID in the posting list.
#   - `score()`: Computes the BM25 score (or similar scoring function) for the current document.
#   - `next()`: Advances the iterator to the next document.
#   - `is_end_list()`: Checks if the iterator has reached the end of the posting list.
#
# - **k** (int, optional):
#   The maximum number of top results to return.
#   Default value is `10`. This determines the capacity of the top-k result set maintained during execution.
#
# ### Internal Attributes / Variables:
# - **top**:
#   An instance of `TopKPriorityQueue` (a priority queue) initialized with capacity `k`. It is used to store the top-k document IDs along with their aggregated scores.
#
# - **current_docid**:
#   The smallest document ID among all the posting lists at the current iteration, obtained via a helper function (e.g., `min_docid(postings)`). This serves as the current candidate document for scoring.
#
# - **score**:
#   A cumulative score computed for the current document by summing individual scores from all posting lists where the document appears.
#
# - **next_docid**:
#   A variable to track the next smallest document ID across all posting lists. It is updated during each iteration to determine the next document to process.
#
# ### Returns:
# - **List of tuples (score, docid)**:
#   The function returns a list where each tuple contains:
#   - **score**: The aggregated BM25 score (or equivalent metric) for a document.
#   - **docid**: The unique identifier of the document.
#
#   The list is **sorted in descending order** by score, ensuring that the most relevant documents (with the highest scores) appear first.
#
# ### Detailed Workflow:
# 1. **Initialization**:
#    - A priority queue `top` is created to hold the top-k results.
#    - The initial `current_docid` is determined by selecting the smallest document ID across all posting lists using `min_docid(postings)`.
#
# 2. **Iterative Processing**:
#    - For the `current_docid`, the function iterates over all posting lists:
#      - If a posting list’s current document ID equals `current_docid`, its score is added to the cumulative `score` and its iterator advances.
#      - Simultaneously, the smallest document ID from the remaining posting lists (i.e., `next_docid`) is determined.
#
# 3. **Result Insertion**:
#    - The document and its cumulative score `(current_docid, score)` are inserted into the `top` priority queue.
#
# 4. **Termination and Output**:
#    - The loop continues until all posting lists are finished (i.e., `current_docid` becomes `math.inf`).
#    - Finally, the function returns the contents of the `top` queue, sorted in descending order by score.
# ---
#
# **Usage Example:**
# After processing, the function might return a list like:
# ```python
# [(23.5, 42), (21.0, 17), (19.8, 3), ...]
# ```
# indicating that document 42 has a score of 23.5, document 17 a score of 21.0, etc.

# %%
def daat(postings, k=10):
    """
    Implements the Document-At-A-Time (DAAT) algorithm for retrieving relevant documents.

    Parameters:
        postings (list[PostingListIterator]): List of posting list iterators, each representing a term's posting list.
        k (int): Maximum number of results to return. Defaults to 10.

    Returns:
        list[tuple]: A list of tuples (score, docid), sorted in descending order of score.
    """
    top = TopKPriorityQueue(k)  # Priority queue to store the top-k results
    current_docid = get_min_docid(postings)  # Initialize with the smallest docid across all postings

    while current_docid != math.inf:
        score = 0
        next_docid = math.inf

        # Compute the score for the current document and find the next docid
        for posting in postings:
            if posting.docid() == current_docid:
                score += posting.score()
                posting.next()  # Move to the next position in the posting list
            if not posting.is_end_list():
                next_docid = min(posting.docid(), next_docid)

        # Insert the current document and its score into the top-k queue
        top.add(current_docid, score)

        # Update to the next document ID to process
        current_docid = next_docid

    # Return the top-k results sorted by score in descending order
    return sorted(top.queue, reverse=True)

# %% [markdown]
# # Getting Output

# %% [markdown]
# ## Retrieving Results for query
# ## Function: retrieve_query_results
#
# ### Purpose:
# The `retrieve_query_results` function is designed to process a text query and retrieve the most relevant documents from a collection using an inverted index. It combines **query preprocessing**, **mapping of query tokens to term IDs**, **retrieval of posting lists**, and finally, ranking of documents via the **Document-At-A-Time (DAAT)** algorithm. This function essentially serves as the entry point for handling user queries in an Information Retrieval (IR) system.
#
# ### Parameters:
# - **query** (str):
#   The input text query provided by the user.
#   *Example:* `"What is the capital of France?"`
#
# - **index** (`InvertedIndex`):
#   An instance of the `InvertedIndex` class, which contains the lexicon, posting lists, document index, and other retrieval statistics necessary for scoring documents.
#   *Key Attributes from the index include:*
#   - `lexicon`: A mapping of tokens to their metadata (e.g., term IDs, frequencies).
#   - `inv`: The inverted index storing document IDs and term frequencies.
#   - `doc`: The document index with document lengths.
#   - `stats`: Collection-wide statistics such as the total number of documents.
#
# - **heap_size** (int, optional):
#   The maximum number of top results to return.
#   Defaults to `10`. This parameter sets the capacity for the result set (the top-k documents).
#
# ### Internal Workflow and Attributes:
# 1. **Query Preprocessing**:
#    - The function first applies the `preprocess` function to the input query.
#    - **Output:** A set of cleaned and stemmed tokens (`qtokens`) is generated from the query.
#    -**Purpose:** This normalization ensures that the query is compatible with the indexed tokens and reduces noise.
#
# 2. **Mapping Tokens to Term IDs**:
#    - The cleaned query tokens are then converted into their corresponding term IDs using `index.get_termids(qtokens)`.
#    - **Output:** A list of term IDs (`qtermids`) representing the query terms.
#    -**Purpose:** This mapping allows the system to locate the relevant posting lists in the inverted index.
#
# 3. **Retrieving Posting Lists**:
#    - The function retrieves posting list iterators for each term ID via `index.get_postings(qtermids)`.
#    - **Output:** A list of `PostingListIterator` objects (`postings`), each representing the documents and term frequencies for a specific query term.
#    - **Purpose:** These posting lists form the basis for scoring documents.
#
# 4. **Document Ranking via DAAT**:
#    - Finally, the function calls the `daat` function, passing the retrieved posting lists and the specified `heap_size`.
#    - **Output:** The `daat` function returns a list of tuples `(score, docid)` sorted in descending order by score, representing the top-ranked documents.
#    -**Purpose:** The DAAT algorithm aggregates scores across posting lists and efficiently identifies the most relevant documents for the query.
#
# ### Returns:
# - **list[tuple]**:
#   A list of tuples where each tuple consists of:
#   - **score** (float): The aggregated relevance score (e.g., BM25 score) for the document.
#   - **docid** (int): The unique identifier of the document.
#
#   The returned list is sorted in **descending order** by score, ensuring that the most relevant documents appear first.
#
# ---
#
# ### Summary:
# The `retrieve_query_results` function integrates query preprocessing, term mapping, posting list retrieval, and document ranking into a single pipeline. It leverages the capabilities of the `InvertedIndex` class and the DAAT algorithm to efficiently handle user queries and return the top-k relevant documents.

# %%
def retrieve_query_results(query, index, heap_size=10):
    """
    Processes a text query and retrieves the most relevant results using an inverted index.

    Parameters:
        query (str): The input text query.
        index (InvertedIndex): The inverted index used to retrieve postings and scores.
        heap_size (int): Maximum number of results to return. Defaults to 10.

    Returns:
        list[tuple]: A list of tuples (score, docid), sorted in descending order of score.
    """
    # Preprocess the query to obtain cleaned and stemmed tokens
    qtokens = set(preprocess(query))

    # Map query tokens to their term IDs
    qtermids = index.get_termids(qtokens)

    # Retrieve postings for the term IDs
    postings = index.get_postings(qtermids)

    # Execute the DAAT algorithm to get the top results
    return daat(postings, heap_size)

# %% [markdown]
# ## Generating TREC for IR
# ## Function: generate_trec_run_file
#
# ### Purpose:
# The `generate_trec_run_file` function generates a TREC-formatted run file from a set of query. It retrieves the top-k relevant documents for each query using an inverted index (if provided) and then formats the results according to the TREC run file specification. This file can be used for evaluation in standard IR benchmarks.
#
# ### Parameters:
# - **queries_df** (DataFrame):
#   A pandas DataFrame containing the query. It must include at least the following columns:
#   - `query`: The text of the query.
#   - `qid`: The unique query identifier.
#
# - **inv_index** (InvertedIndex or None):
#   An instance of the `InvertedIndex` class used for retrieving document scores based on the query.
#   - If provided, the function uses `retrieve_query_results` to generate the top-k results.
#   - If `None`, it assumes that the `queries_df` DataFrame already contains precomputed results (with columns like `docno`, `rank`, and `score`).
#
# - **file_name** (str):
#   The name (and optionally the path) of the output file where the TREC run file data will be saved.
#
# ### Behavior and Internal Workflow:
# 1. **Set Retrieval Size**:
#    - A constant `k` is set to `10`, meaning the function will retrieve up to 10 results per query.
#
# 2. **Result Generation (if inv_index is provided)**:
#    - For each query in the `queries_df` DataFrame:
#      - The query text is processed by `retrieve_query_results` to obtain a list of results, where each result is a tuple `(score, docid)`.
#      - The function pairs each result with the query ID and formats it according to the TREC run file format:
#        `<query_id> Q0 <docno> <rank> <score> run.txt`
#      - All formatted strings are collected into a list called `results`.
#
# 3. **Result Generation (if inv_index is None)**:
#    - For each row, it directly uses the provided `qid`, `docno`, `rank` (starts from 1 then decrease incrementally), and `score` values to format the result string.
#
# 4. **File Output**:
#    - The list of formatted result strings is written to the specified file (`file_name`) using standard file I/O operations.
#
# ### Returns:
# - **None**:
#   The function writes the formatted run results directly to the specified file. It does not return any value, but its output is the generated run file in TREC format.
#
# ---

# %%
def generate_trec_run_file(queries_df, inv_index, output_file):
    """
    Generates a TREC run file from queries_df and an inverted index.

    Parameters:
        queries_df (DataFrame): DataFrame containing queries with columns 'query' and 'qid'.
        inv_index (InvertedIndex or None): Inverted index used to retrieve document scores.
        file_name (str): Name of the output file where the run data will be saved.

    Behavior:
        - For each query, retrieves the top-k results using `retrieve_query_results` if `inv_index` is provided.
        - Formats the results in TREC run file format:
            `<query_id> Q0 <docno> <rank> <score> run.txt`
    """
    run_data = []

    for query in queries_df.itertuples(index=False):
        query_id, query_text = query.qid, query.query
        results = retrieve_query_results(query_text, inv_index, heap_size=10)

        for rank, (score, docid) in enumerate(results, start=1):
            run_data.append(f"{query_id} Q0 {docid} {rank} {score:.6f} run.txt")

    # Save run file
    with open(output_file, "w") as f:
        f.writelines("\n".join(run_data))
    print(f"Run file saved as: {output_file}")

# %% [markdown]
# #Evaluation

# %% [markdown]
# ## Calculating Evaluation Metrices
#
# ##  Function: run_trec_evaluation
#
# ### Purpose:
# The `run_trec_evaluation` function orchestrates a full TREC evaluation process to measure the effectiveness of an Information Retrieval (IR) system. It generates a run file using a provided generator function, loads both the run file and the corresponding relevance judgments (qrels), and then computes a set of evaluation metrics. These metrics include **Precision at 5 (P@5)**, **nDCG at 10 (nDCG@10)**, **Average Precision (AP)**, because they each capture different aspects of retrieval effectiveness. Since these are standard evaluation measures in IR research, they also allow the performance of my system to be compared with other systems in a consistent and reproducible manner.
#
# ### Parameters:
# - **queries_df** (DataFrame):
#   A pandas DataFrame containing the queries. It typically includes at least:
#   - `query`: The text of the query.
#   - `qid`: The unique query identifier.
#
# - **inv_index** (InvertedIndex):
#   An instance of the `InvertedIndex` class used to retrieve relevant documents for each query.
#   - This object provides the necessary posting lists and scoring functions for the retrieval process.
#
# - **text_file** (str):
#   The file name (and optionally path) where the run file (i.e., the retrieval results) will be saved.
#   - The run file follows the TREC format and is used as input for evaluation.
#
# - **run_file_generator** (function):
#   A function responsible for generating the run file. It is expected to accept the following parameters:
#   - `queries_df`, `inv_index`, `text_file`, and any additional arguments provided via `*args`.
#   - This function encapsulates the retrieval logic (e.g., calling `retrieve_query_results` or `daat`) and writes the formatted output to `text_file`.
#
# - **\*args**:
#   Additional arguments that are forwarded to the `run_file_generator` function, allowing further customization of the run file generation process.
#
# ### Internal Workflow / Attributes:
#
# 1. **Loading Evaluation Files:**
#    - The function then loads the relevance judgments (qrels) from a pre-specified file (`Files/qrels.txt`) using `ir_measures.read_trec_qrels`.
#    - It also loads the run file generated earlier using `ir_measures.read_trec_run`.
#
# 2. **Aggregate Evaluation:**
#    - Aggregate metrics are calculated using `ir_measures.calc_aggregate`, which computes measures such as:
#      - Precision at 5 (P@5)
#      - nDCG at 10 (nDCG@10)
#      - Average Precision (AP)
#    - These metrics are printed to provide an overview of the system's performance.
#
# 3. **Per-Query Evaluation:**
#    - The function computes detailed per-query metrics using `ir_measures.iter_calc` for each measure.
#    - The results are stored in dictionaries keyed by the query identifier (`query_id`), with each value representing the computed metric for that query:
#      - `Pat5_list`: Precision at 5 per query.
#      - `nDCGat10_list`: nDCG at 10 per query.
#      - `AP_list`: Average Precision per query.
#
# ### Returns:
# - **tuple**:
#   The function returns a tuple containing five dictionaries:
#   1. **Pat5_list** (dict):
#      - Keys: Query IDs.
#      - Values: Precision at 5 for each query.
#   2. **nDCGat10_list** (dict):
#      - Keys: Query IDs.
#      - Values: Normalized Discounted Cumulative Gain at 10 for each query.
#   3. **AP_list** (dict):
#      - Keys: Query IDs.
#      - Values: Average Precision for each query.
#
# ### Summary:
# The `run_trec_evaluation` function is a comprehensive evaluation routine that:
# - Generates a TREC-formatted run file using a provided retrieval method.
# - Loads the run file and corresponding qrels.
# - Computes and prints aggregate evaluation metrics.
# - Returns detailed per-query metrics for further analysis.
# This function plays a critical role in quantifying the performance of an IR system in a standardized manner.
#
# ### Evaluation Metric Formulas
#
# 1. **Precision at K (P@K):**
#
#    $$P@K = \frac{\text{Number of relevant documents in the top }K}{K}$$
#
#    - *Interpretation:* This metric represents the fraction of the top K retrieved documents that are relevant to the query.
#
# 2. **Normalized Discounted Cumulative Gain at K (nDCG@K):**
#
#    $$\text{DCG@K} = \sum_{i=1}^{K} \frac{2^{rel_i} - 1}{\log_2(i+1)}$$
#
#    $$\text{nDCG@K} = \frac{\text{DCG@K}}{\text{IDCG@K}}$$
#    - *Interpretation:* DCG@K accumulates the gains from each relevant document, discounted by their rank. nDCG@K normalizes this value by the ideal DCG (IDCG@K), thus providing a measure of ranking quality that accounts for both relevance and position.
#
# 3. **Average Precision (AP):**
#    $$AP = \frac{1}{R} \sum_{k=1}^{N} P(k) \times rel(k)$$
#    - Where:
#      - \( P(k) \) is the precision at rank \( k \),
#      - \(rel(k) \) is an indicator function that equals 1 if the document at rank \( k \) is relevant, and 0 otherwise,
#      - \( R \) is the total number of relevant documents for the query,
#      - \( N \) is the total number of retrieved documents.
#    - *Interpretation:* AP averages the precision values at the ranks where relevant documents occur, providing a single-number summary of the precision-recall curve.

# %%
from ir_measures import P, nDCG, AP
def run_trec_evaluation(queries_df, inv_index, text_file, run_file_generator, *args):
    """
    Executes a TREC evaluation for information retrieval performance.

    Parameters:
        queries_df (DataFrame): queries to be analyzed, typically containing queries and their IDs.
        inv_index (InvertedIndex): The inverted index used for retrieving documents.
        text_file (str): File name where the run file will be saved.
        run_file_generator (function): Function to generate the run file. Expected to accept:
            (queries_df, inv_index, text_file, *args).
        *args: Additional arguments to be passed to `run_file_generator`.

    Returns:
        tuple: Dictionaries containing evaluation metrics per query:
            - Pat5_list (dict): Precision at 5 (P@5) for each query.
            - nDCGat10_list (dict): Normalized Discounted Cumulative Gain at 10 (nDCG@10).
            - AP_list (dict): Average Precision (AP) for each query.

    Prints:
        Aggregate evaluation metrics for the dataset using the specified measures.
    """

    # Load qrels and run files for evaluation
    qrels = list(ir_measures.read_trec_qrels('Files/qrels.txt'))
    run = list(ir_measures.read_trec_run(text_file))

    # Print aggregate evaluation metrics
    print(ir_measures.calc_aggregate([P@5, nDCG@10, AP], qrels, run))

    # Compute per-query metrics
    Pat5_list = {m.query_id: m.value for m in ir_measures.iter_calc([P@5], qrels, run)}
    nDCGat10_list = {m.query_id: m.value for m in ir_measures.iter_calc([nDCG@10], qrels, run)}
    AP_list = {m.query_id: m.value for m in ir_measures.iter_calc([AP], qrels, run)}

    return Pat5_list, nDCGat10_list, AP_list

# %%
import pyterrier as pt
import pandas as pd
import ir_measures
from ir_measures import P, nDCG, AP
import os

dataset = pt.get_dataset('irds:vaswani')

# Load dataset components
df_docs = pd.DataFrame(list(dataset.get_corpus_iter()))  # Convert corpus to DataFrame
df_queries = dataset.get_topics()  # Queries
df_qrels = dataset.get_qrels()  # Qrels (Ground truth relevance judgments)

print("✅ Dataset Loaded")
print(df_docs.head(), "\n")
print(df_queries.head(), "\n")
print(df_qrels.head(), "\n")

# Preprocess the text using your custom function
df_docs["tokens"] = df_docs["text"].apply(preprocess)
print("✅ Documents Preprocessed")

# Build the index using your custom index function
lexicon, inv, doc_index, direct_index, stats = build_index(df_docs)
print("\n=== Index Statistics ===")
print(f"Number of documents: {stats['num_docs']}")
print(f"Number of unique terms: {stats['num_terms']}")
print(f"Total tokens in collection: {stats['num_tokens']}")

# Create Inverted Index Instance with BM25
bm25_k = 1.2
bm25_b = 0.75
ir_index = InvertedIndex(lexicon, inv, doc_index, direct_index, stats, bm25_k, bm25_b)
print("✅ Custom Index Created")



# Specify run file name
run_file = "vaswani_run.txt"
generate_trec_run_file(df_queries, ir_index, run_file)

# Ensure the "Files" directory exists
os.makedirs("Files", exist_ok=True)

# Save qrels file in TREC format
qrels_file = "Files/qrels.txt"
# Ensure qrels have the required 4 columns: <qid> <iteration> <docno> <label>
df_qrels["iteration"] = 0  # Add a default iteration column
df_qrels.to_csv(qrels_file, sep=" ", header=False, index=False, columns=["qid", "iteration", "docno", "label"])
print(f"✅ Qrels file saved as: {qrels_file}")

# Call your evaluation function
metrics = run_trec_evaluation(df_queries, ir_index, run_file, generate_trec_run_file)

# Print Evaluation Metrics
Pat5_list, nDCGat10_list, AP_list = metrics
print("\n=== Evaluation Metrics ===")
print("P@5:", Pat5_list)
print("nDCG@10:", nDCGat10_list)
print("AP:", AP_list)

# %% [markdown]
# ## Evaluation Metrics Values
#
# In this project, we indexed and retrieved documents from the **Vaswani dataset**, which contains over **11,000 scientific abstracts**. After **preprocessing** (tokenization, stopword removal, and stemming), a **custom BM25-based inverted index** was built. We evaluated the retrieval effectiveness using standard IR metrics—**Precision at 5 (P@5)**, **nDCG@10**, and **Average Precision (AP)**—by comparing our system’s output with the ground-truth relevance judgments (**qrels**).
#
# ## Index Statistics
# - **Number of Documents:** 11,429
# - **Unique Terms:** 7,638
# - **Total Tokens:** 291,789
#
# ## Aggregate Metrics
# - **P@5 ≈ 0.458:** On average, about 46% of the top 5 documents per query are relevant.
# - **nDCG@10 ≈ 0.438:** Ranking quality is moderate within the top 10, with relevant documents often placed fairly high but still room to improve.
# - **AP ≈ 0.166:** While some queries achieve high precision, others retrieve fewer relevant documents (or rank them lower), which lowers the overall average precision.

# %% [markdown]
# ## Evaluation Metrics Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# Convert dictionaries to a DataFrame
df_results = pd.DataFrame({
    'Query': list(Pat5_list.keys()),
    'P@5': list(Pat5_list.values()),
    'nDCG@10': [nDCGat10_list[q] for q in Pat5_list.keys()],
    'AP': [AP_list[q] for q in Pat5_list.keys()]
})

# Create a box plot for the three metrics
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_results[['P@5', 'nDCG@10', 'AP']])
plt.title("Distribution of Evaluation Metrics Across Queries")
plt.ylabel("Metric Value")
plt.show()

# %% [markdown]
# ### Box Plot of P@5, nDCG@10, and AP
#
# This box plot displays the distribution of each metric across all queries. It quickly reveals whether most queries cluster around a certain performance range or if there is wide variance. For example, we can observe that **P@5** has a higher median than **AP**, which is typical since **AP** considers the entire ranking.

# %%
import seaborn as sns

df = pd.DataFrame({'Query ID': list(Pat5_list.keys()), 'P@5': list(Pat5_list.values()), 'nDCG@10': list(nDCGat10_list.values())})
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='P@5', y='nDCG@10', palette='coolwarm', s=100)
plt.title('P@5 vs. nDCG@10 for Queries')
plt.xlabel('Precision at 5')
plt.ylabel('nDCG@10')
plt.show()

# %% [markdown]
# ### Scatter Plot: P@5 vs. nDCG@10
#
# In this plot, each point represents a single query. The **x-axis** corresponds to **P@5** (Precision at 5) and the **y-axis** corresponds to **nDCG@10** (Normalized Discounted Cumulative Gain at 10).
#
# - **Top-right points:** Indicate queries where both P@5 and nDCG@10 are high, meaning that the top-ranked documents are both highly relevant and well-ordered.
# - **Bottom-left points:** Indicate queries with low precision at rank 5 and poor ranking quality overall.
#
# This visualization helps assess the correlation between the metrics. If P@5 is high for a query, nDCG@10 tends to be high as well, which suggests that the retrieval system is consistent in ranking relevant documents at the top.

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(list(Pat5_list.items()), columns=['Query ID', 'P@5'])
df.plot(x='Query ID', y='P@5', kind='bar', figsize=(12, 5), color='skyblue')
plt.xlabel('Query ID')
plt.ylabel('Precision at 5')
plt.title('P@5 Across Queries')
plt.show()

# %%
df = pd.DataFrame(list(nDCGat10_list.items()), columns=['Query ID', 'nDCG@10'])
df.plot(x='Query ID', y='nDCG@10', kind='bar', figsize=(12, 5), color='salmon')
plt.xlabel('Query ID')
plt.ylabel('nDCG@10')
plt.title('Normalized Discounted Cumulative Gain (nDCG@10)')
plt.show()

# %% [markdown]
# ### Bar Chart of Per-Query Metrics
#
# bar charts for each query’s metric value (e.g., P@5 or nDCG@10).
#
# **Interpretation:**
# - Helps pinpoint which queries are “easy” (high metric values) versus “hard” (low metric values).
# - Identifies outliers—queries that perform exceptionally well or poorly.
#
# **Why It’s Useful:**
# - Facilitates a query-by-query diagnosis. If certain queries systematically fail, you can investigate what makes those queries more challenging (e.g., ambiguous terms, lack of relevant documents, or domain-specific vocabulary).

# %% [markdown]
# ## Conclusion
#
# The retrieval system demonstrates **moderate effectiveness** on the Vaswani dataset. While some queries show near-perfect precision (P@5 = 1.0), others retrieve few or no relevant documents at the top. The **nDCG@10** and **AP** values confirm that many relevant documents are ranked relatively well, but there is still significant variability across queries.
#
# **Future improvements** might include:
# - **Refined Preprocessing:** More domain-focused tokenization or synonyms for scientific terms.
# - **Advanced Ranking Models:** Neural re-rankers or query expansion techniques to improve ranking consistency.
# - **Error Analysis:** Identifying patterns in queries that perform poorly to guide targeted enhancements.
#
# With these optimizations, the system could yield more **consistent** and **higher-quality** rankings across all queries in this **scientific abstracts** domain.
